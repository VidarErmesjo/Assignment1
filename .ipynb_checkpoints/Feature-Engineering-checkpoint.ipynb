# %% [markdown]
# # Feature-Engineering
# ## DAVE3625 - Introduksjon til Kunstig Intelligens
# Collaborators: Vidar Ermesjø (s318075) / Sigurd Blankholm Heggemsnes (s313853)

# %%
import pandas as panda
import matplotlib
from matplotlib import pyplot as plot

# %% [markdown]
# ### Dataset:

# %%
data = panda.read_csv("Ruter_data.csv", skiprows=0, delimiter=';', names=None)

# %%
# Random samples from dataset:
data.sample(10)
# Out:
#                                 TurId        Dato  Fylke    Område  \
# 5987  30010-2020-07-29T14:44:00+02:00  29/07/2020   Oslo  Indre By
# 1880  12008-2020-08-24T13:56:00+02:00  24/08/2020  Viken   Nordøst
# 5783   3102-2020-06-01T21:36:00+02:00  01/06/2020   Oslo  Indre By
# 199    7404-2020-08-05T00:38:00+02:00  04/08/2020   Oslo       Sør
# 4858  47005-2020-07-14T07:30:00+02:00  14/07/2020  Viken   Nordøst
# 1377  34017-2020-08-12T12:12:00+02:00  12/08/2020  Viken   Nordøst
# 4842  24005-2020-07-28T09:57:00+02:00  28/07/2020  Viken      Vest
# 2041  43003-2020-07-02T12:55:00+02:00  02/07/2020  Viken   Nordøst
# 4013  25042-2020-08-28T17:04:00+02:00  28/08/2020  Viken      Vest
# 2898  47001-2020-08-11T04:57:00+02:00  11/08/2020  Viken   Nordøst
#
#          Kommune                       Holdeplass_Fra  \
# 5987  Gamle Oslo      Helsfyr T  (plf. L mot sentrum)
# 1880    Rælingen                     Løvenstad senter
# 5783     Sentrum  Wessels plass  (mot Jernbanetorget)
# 199   Nordstrand        Bakkerudveien  (mot Munkerud)
# 4858  Lillestrøm                     Riddersand skole
# 1377    Rælingen                          Eikeliveien
# 4842       Bærum                          Tanum skole
# 2041  Ullensaker                             Mogreina
# 4013       Asker                         Nedre Berger
# 2898  Lillestrøm                              Vinsnes
#
#                       Holdeplass_Til Linjetype Linjefylke Linjenavn  \
# 5987  Etterstadgata  (mot Galgeberg)     Lokal      Viken       300
# 1880                     Skytilveien     Lokal      Viken       310
# 5783           Kvadraturen (mot øst)     Lokal       Oslo        31
# 199     Freidigveien  (mot Munkerud)     Lokal       Oslo        74
# 4858                           Løken     Lokal      Viken       480
# 1377     Linjeveien (I Rælingsveien)     Lokal      Viken       360
# 4842                         Reverud     Lokal      Viken       245
# 2041                 Mogreinakrysset     Lokal      Viken       430
# 4013                          Nesbru     Lokal      Viken       250
# 2898                            Tuen     Lokal      Viken       470
#
#       Linjeretning Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 5987             0                                 15:14:35
# 1880             1                                 14:20:23
# 5783             0                                 22:01:12
# 199              0                                 25:00:38
# 4858             1                                 07:47:07
# 1377             0                                 12:41:48
# 4842             0                                 09:58:08
# 2041             1                                 13:10:18
# 4013             1                                 17:45:19
# 2898             0                                 05:39:50
#
#      Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 5987                                15:15:14
# 1880                                14:21:25
# 5783                                22:01:43
# 199                                 25:00:45
# 4858                                07:47:17
# 1377                                12:41:54
# 4842                                09:58:32
# 2041                                13:10:22
# 4013                                17:45:45
# 2898                                05:39:53
#
#      Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 5987                                  15:08:00
# 1880                                  14:19:00
# 5783                                  22:01:00
# 199                                   25:00:00
# 4858                                  07:44:00
# 1377                                  12:41:00
# 4842                                  09:58:00
# 2041                                  13:10:00
# 4013                                  17:38:00
# 2898                                  05:40:00
#
#      Tidspunkt_Planlagt_Avgang_Holdeplass_Fra  Kjøretøy_Kapasitet  \
# 5987                                 15:08:00                 106
# 1880                                 14:19:00                  72
# 5783                                 22:01:00                 151
# 199                                  25:00:00                  72
# 4858                                 07:44:00                 106
# 1377                                 12:41:00                 105
# 4842                                 09:58:00                  69
# 2041                                 13:10:00                 106
# 4013                                 17:38:00                 112
# 2898                                 05:40:00                 106
#
#       Passasjerer_Ombord
# 5987                  11
# 1880                  25
# 5783                  15
# 199                    1
# 4858                   2
# 1377                   5
# 4842                   1
# 2041                   0
# 4013                  10
# 2898                   8

# %%
# Number of records and fieldnames in dataset:
data.shape
# Out:
# (6000, 17)

# %%
# HÆÆÆ?
plot.hist(data.Passasjerer_Ombord, bins=25, rwidth=1)
plot.xlabel('Reisende')
plot.ylabel('Kapasitet')
plot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-e49937179989> in <module>
#       1 # HÆÆÆ?
# ----> 2 plot.hist(data.Passasjerer_Ombord, data.Kjøretøy_Kapasitet, bins=25, rwidth=1)
#       3 plot.xlabel('Reisende')
#       4 plot.ylabel('Kapasitet')
#       5 plot.show()
#
# TypeError: hist() got multiple values for argument 'bins'
