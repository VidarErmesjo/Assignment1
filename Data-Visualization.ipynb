# %% [markdown]
# # Data-Visualization:
# ## DAVE3625 - Introduksjon til Kunstig Intelligens
# Collaborators: Vidar Ermesjø (s318075) / Sigurd Blankholm Heggemsnes (s313853)

# %%
import pandas as panda
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-998914a55fa8> in <module>
#       1 import pandas as panda
# ----> 2 import seaborn as sea
#
# ModuleNotFoundError: No module named 'seaborn'

# %% [markdown]
# ### Dataset:

# %%
data = panda.read_csv("Ruter_data.csv", skiprows=0, delimiter=';', names=None)
data.head()
# Out:
#                              TurId        Dato  Fylke Område Kommune  \
# 0  15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken   Vest   Bærum
# 1  15002-2020-08-15T12:54:00+02:00  15/08/2020  Viken   Vest   Bærum
# 2  15004-2020-08-03T09:54:00+02:00  03/08/2020  Viken   Vest   Bærum
# 3  15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken   Vest   Bærum
# 4  15002-2020-08-27T07:15:00+02:00  27/08/2020  Viken   Vest   Bærum
#
#                   Holdeplass_Fra                        Holdeplass_Til  \
# 0                    Nordliveien                             Tjernsmyr
# 1               Nadderud stadion  Bekkestua bussterminal (Plattform C)
# 2               Ringstabekkveien                               Skallum
# 3                      Gruvemyra                              Gullhaug
# 4  Lysaker stasjon (Plattform A)                             Tjernsmyr
#
#   Linjetype Linjefylke Linjenavn  Linjeretning  \
# 0     Lokal      Viken       150             0
# ...

# %% [markdown]
# ### Scatter plot:

# %%
data.plot.scatter(x='Dato', y='Passasjerer_Ombord', title='Scatter plot')
# Out:
# <AxesSubplot:title={'center':'Scatter plot'}, xlabel='Dato', ylabel='Passasjerer_Ombord'>

# %% [markdown]
# ### Line chart:

# %%
data.drop(['TurId', 'Fylke', 'Område', 'Kommune', 'Holdeplass_Fra', 'Holdeplass_Til', 'Linjetype', 'Linjefylke', 'Linjenavn', 'Linjeretning'], axis=1).plot.line(title="Line chart")
# Out:
# <AxesSubplot:title={'center':'Line chart'}>

# %% [markdown]
# ### Histogram:

# %%
data['Passasjerer_Ombord'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.plot.hist(subplots=True, layout=(2,2), figsize=(10, 10), bins=20)
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)

# %% [markdown]
# ### Bar chart:

# %%
data['Kjøretøy_Kapasitet'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data.groupby("Dato").Passasjerer_Ombord.mean().sort_values(ascending=False)[:25].plot.bar()
# Out:
# <AxesSubplot:xlabel='Dato'>
